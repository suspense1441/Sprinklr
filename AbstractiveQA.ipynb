# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 84.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.3 MB/s eta 0:00:00
# ...

# %%
# !pip install datasets

# %%
# !pip install accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 12.1 MB/s eta 0:00:00
# ...

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.2 MB/s eta 0:00:00
# ...

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
tokenizer1 = T5Tokenizer.from_pretrained("google/flan-t5-small")
model1 = T5ForConditionalGeneration.from_pretrained("google/flan-t5-small", device_map="auto")

input_text = "Context: It's official - IBM has acquired Red Hat! The deal was announced in October 2018. IBM acquired all of the issued and outstanding common shares of Red Hat for $190.00 per share in cash, representing a total equity value of approximately $34 billion. The acquisition redefines the cloud market for business. Red Hat’s open hybrid cloud technologies are now paired with the unmatched scale and depth of IBM’s innovation and industry expertise, and sales leadership in more than 175 countries. Together, IBM and Red Hat will accelerate innovation by offering a next-generation hybrid multicloud platform. Based on open source technologies, such as Linux and Kubernetes, the platform will allow businesses to securely deploy, run and manage data and applications on-premises and on private and multiple public clouds. Question: When and for how much did IBM acquire Red Hat for? "
input_ids = tokenizer1(input_text, return_tensors="pt").input_ids.to("cuda")

outputs = model1.generate(input_ids, min_length=30, max_length=100, early_stopping=True)
print(tokenizer1.decode(outputs[0]))
# Out:
# ...
# <pad> October 2018 - October 2018 - October 2018 - October 2018 - October 2018 - October 2018 - October 2018 - October 2018</s>

# %%
tokenizer2 = T5Tokenizer.from_pretrained("google/flan-t5-large")
model2 = T5ForConditionalGeneration.from_pretrained("google/flan-t5-large", device_map="auto")

input_text = "Context: It's official - IBM has acquired Red Hat! The deal was announced in October 2018. IBM acquired all of the issued and outstanding common shares of Red Hat for $190.00 per share in cash, representing a total equity value of approximately $34 billion. The acquisition redefines the cloud market for business. Red Hat’s open hybrid cloud technologies are now paired with the unmatched scale and depth of IBM’s innovation and industry expertise, and sales leadership in more than 175 countries. Together, IBM and Red Hat will accelerate innovation by offering a next-generation hybrid multicloud platform. Based on open source technologies, such as Linux and Kubernetes, the platform will allow businesses to securely deploy, run and manage data and applications on-premises and on private and multiple public clouds. Question: When and for how much did IBM acquire Red Hat for? "
input_ids = tokenizer2(input_text, return_tensors="pt").input_ids.to("cuda")

outputs = model2.generate(input_ids, min_length=20, max_length=100, early_stopping=True)
print(tokenizer2.decode(outputs[0]))
# Out:
# <pad> October 2018 and for $190.00 per share in cash, representing a total equity value of approximately $34 billion</s>

# %%
tokenizer3 = T5Tokenizer.from_pretrained("google/flan-t5-xl")
model3 = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xl", device_map="auto")

input_text = "Context: It's official - IBM has acquired Red Hat! The deal was announced in October 2018. IBM acquired all of the issued and outstanding common shares of Red Hat for $190.00 per share in cash, representing a total equity value of approximately $34 billion. The acquisition redefines the cloud market for business. Red Hat’s open hybrid cloud technologies are now paired with the unmatched scale and depth of IBM’s innovation and industry expertise, and sales leadership in more than 175 countries. Together, IBM and Red Hat will accelerate innovation by offering a next-generation hybrid multicloud platform. Based on open source technologies, such as Linux and Kubernetes, the platform will allow businesses to securely deploy, run and manage data and applications on-premises and on private and multiple public clouds. Question: When and for how much did IBM acquire Red Hat for? "
input_ids = tokenizer3(input_text, return_tensors="pt").input_ids.to("cuda")

outputs = model3.generate(input_ids, min_length=10, max_length=100, early_stopping=True)
print(tokenizer3.decode(outputs[0]))
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# <pad> October 2018 for $190.00 per share in cash, representing a total equity value of approximately $34 billion</s>

# %%
tokenizer4 = T5Tokenizer.from_pretrained("google/flan-t5-xxl")
model4 = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xxl", device_map="auto")

input_text = "Context: It's official - IBM has acquired Red Hat! The deal was announced in October 2018. IBM acquired all of the issued and outstanding common shares of Red Hat for $190.00 per share in cash, representing a total equity value of approximately $34 billion. The acquisition redefines the cloud market for business. Red Hat’s open hybrid cloud technologies are now paired with the unmatched scale and depth of IBM’s innovation and industry expertise, and sales leadership in more than 175 countries. Together, IBM and Red Hat will accelerate innovation by offering a next-generation hybrid multicloud platform. Based on open source technologies, such as Linux and Kubernetes, the platform will allow businesses to securely deploy, run and manage data and applications on-premises and on private and multiple public clouds. Question: When and for how much did IBM acquire Red Hat for? "
input_ids = tokenizer4(input_text, return_tensors="pt").input_ids.to("cuda")

outputs = model4.generate(input_ids, max_length=100, early_stopping=True)
print(tokenizer4.decode(outputs[0]))

# %%
contexts = {'context': "It's official - IBM has acquired Red Hat! The deal was announced in October 2018. IBM acquired all of the issued and outstanding common shares of Red Hat for $190.00 per share in cash, representing a total equity value of approximately $34 billion. The acquisition redefines the cloud market for business. Red Hat’s open hybrid cloud technologies are now paired with the unmatched scale and depth of IBM’s innovation and industry expertise, and sales leadership in more than 175 countries. Together, IBM and Red Hat will accelerate innovation by offering a next-generation hybrid multicloud platform. Based on open source technologies, such as Linux and Kubernetes, the platform will allow businesses to securely deploy, run and manage data and applications on-premises and on private and multiple public clouds."}

# %%
print(contexts['context'])
# Out:
# It's official - IBM has acquired Red Hat! The deal was announced in October 2018. IBM acquired all of the issued and outstanding common shares of Red Hat for $190.00 per share in cash, representing a total equity value of approximately $34 billion. The acquisition redefines the cloud market for business. Red Hat’s open hybrid cloud technologies are now paired with the unmatched scale and depth of IBM’s innovation and industry expertise, and sales leadership in more than 175 countries. Together, IBM and Red Hat will accelerate innovation by offering a next-generation hybrid multicloud platform. Based on open source technologies, such as Linux and Kubernetes, the platform will allow businesses to securely deploy, run and manage data and applications on-premises and on private and multiple public clouds.

# %%
query = "When and for how much did IBM acquire Red Hat for?"

# %%
data = "Context:It's official - IBM has acquired Red Hat! The deal was announced in October 2018. IBM acquired all of the issued and outstanding common shares of Red Hat for $190.00 per share in cash, representing a total equity value of approximately $34 billion. The acquisition redefines the cloud market for business. Red Hat’s open hybrid cloud technologies are now paired with the unmatched scale and depth of IBM’s innovation and industry expertise, and sales leadership in more than 175 countries. Together, IBM and Red Hat will accelerate innovation by offering a next-generation hybrid multicloud platform. Based on open source technologies, such as Linux and Kubernetes, the platform will allow businesses to securely deploy, run and manage data and applications on-premises and on private and multiple public clouds. Question: When and for how much did IBM acquire Red Hat for? "

# %%
model_gpt4all.generate(data)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'model_gpt4all' is not defined

# %%
for context in contexts['context']:
    answer = seq2seq(
        f"question: {query} context: {context}",
        num_beams=4,
        do_sample=True,
        temperature=1.5,
        max_length=64
    )
    print(answer)
# Out:
# [{'generated_text': " Yes, I don't think it's only the Superbowl, but the NFLPA and the NFLPA are pretty strict about who gets to be on the field during the game and what they can and can't wear and what they can and cannot do in the locker room and what they can't and cannot do"}]
# [{'generated_text': " It's a big deal for an NFL team. It's an opportunity to be in the spotlight, to sell tickets, and an opportunity to be seen on television. It's the most prestigious game in the world. A team like the Green Bay Packers will do anything to be in the spotlight."}]
# [{'generated_text': " Yes. If you don't want to play in a Super Bowl every year, there is no other reason. The money and the prestige of being in the Super Bowl. There is also the opportunity to be able to say that you have played at the Super Bowl last year. If you don't, you are"}]
# ...
