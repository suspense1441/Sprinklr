# %% [markdown]
# ### GitHub

# %%
# !git config --global user.email "tusharbokade003@gmail.com"
# !git config --global user.name "Tushar Bokade"

# %%
token = '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'
username = 'suspense1441'
repo = 'LinkGoogleColab'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'LinkGoogleColab'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 2.24 KiB | 2.24 MiB/s, done.

# %%
# %cd {repo}
# Out:
# /content/LinkGoogleColab

# %%
# %ls
# Out:
# 26May.ipynb  29May.ipynb

# %%
# !cp /content/drive/MyDrive/Sprinklr_Internship/29May.ipynb .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   29May.ipynb

# %%
# !git log
# Out:
# commit 901d1dc85458ac0bd6798aad19c721156c9f6ae3 (HEAD -> main, origin/main, origin/HEAD)
# Author: Tushar Bokade <80628285+suspense1441@users.noreply.github.com>
# Date:   Mon May 29 11:28:56 2023 +0530
#
#     Add files via upload

# %%
# !git add --all

# %%
# !git commit -a -m "Added 2nd file"
# Out:
# [main f3a7ce7] Added 2nd file
#  1 file changed, 1 insertion(+)
#  create mode 100644 29May.ipynb

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/suspense1441/LinkGoogleColab (fetch)
# origin	https://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@github.com/suspense1441/LinkGoogleColab (push)

# %%
# !git push origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 11.11 KiB | 5.55 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/suspense1441/LinkGoogleColab
#    901d1dc..f3a7ce7  main -> main

# %% [markdown]
# ### Hugging Face

# %%
zsdsdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a523c1b48eb2> in <cell line: 1>()
# ----> 1 zsdsdf
#
# NameError: name 'zsdsdf' is not defined

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for my mentors reply for the last 3 days.")

# %%
classifier = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
classifier(
    "This is a course about the Transformers library.",
    candidate_labels=["fear", "happy"],
)
# Out:
# {'sequence': 'This is a course about the Transformers library.',
#  'labels': ['happy', 'fear'],
#  'scores': [0.5377991795539856, 0.4622008502483368]}

# %%
generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
generator("If my mentor doesn't reply by today then")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'If my mentor doesn\'t reply by today then you\'ll still have to wait a few weeks for feedback." - "In the end I don\'t even think it was that big of a deal." - "Now you are right." - "But I'}]

# %%
arr = [[1,2], [3,2], [3,4], [5,4]]
np.argmax(arr, 1)
# Out:
# array([1, 0, 1, 0])

# %%
# Out:
# 4
