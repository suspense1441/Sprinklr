# %%
# %cd 'Sprinklr'
# Out:
# /content/Sprinklr

# %%
# !mv /content/drive/MyDrive/Colab_Notebooks/DollyPreprocess.ipynb

# %% [markdown]
# ### GitHub Code

# %%
# !git config --global user.email "tusharbokade003@gmail.com"
# !git config --global user.name "Tushar Bokade"

# %%
token = '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'
username = 'suspense1441'
repo = 'Sprinklr'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'Sprinklr'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 14 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (14/14), 1.86 MiB | 991.00 KiB/s, done.

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git add --all
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git commit -a -m "Added 2nd file"

# %%
# !git remote -v

# %%
# !git push origin main
